# %%
import pandas as pd

# %%
# interpolate() function is basically used to fill NaN values in dataframe or series.

df = pd.read_csv(r"C:\Users\Gitanshu\Downloads\Students_10.csv")
df
# Out:
#         Date  Student ID  Class Section  Study hrs  Percentage
# 0   1/7/2019      1001.0     10       A        2.0        50.0
# 1   1/8/2019      1002.0     10     NaN        NaN        80.0
# 2   1/9/2019         NaN     10     NaN        3.0        60.0
# 3  1/10/2019         NaN     11     NaN        0.0         NaN
# 4  1/11/2019      1005.0     11       A        4.0         NaN
# 5  1/12/2019         NaN     11       D       10.0         NaN
# 6  1/13/2019      1007.0     12       B        4.0        80.0
# 7  1/14/2019      1008.0     12       C        NaN        90.0
# 8  1/15/2019      1009.0     12       A        NaN        60.0
# 9  1/16/2019      1010.0     12       D        6.0        85.0

# %%
df.interpolate() # Sirf Numeric values
# Out:
#         Date  Student ID  Class Section  Study hrs  Percentage
# 0   1/7/2019      1001.0     10       A   2.000000        50.0
# 1   1/8/2019      1002.0     10     NaN   2.500000        80.0
# 2   1/9/2019      1003.0     10     NaN   3.000000        60.0
# 3  1/10/2019      1004.0     11     NaN   0.000000        65.0
# 4  1/11/2019      1005.0     11       A   4.000000        70.0
# 5  1/12/2019      1006.0     11       D  10.000000        75.0
# 6  1/13/2019      1007.0     12       B   4.000000        80.0
# 7  1/14/2019      1008.0     12       C   4.666667        90.0
# 8  1/15/2019      1009.0     12       A   5.333333        60.0
# 9  1/16/2019      1010.0     12       D   6.000000        85.0

# %%
df.interpolate(method='linear')
# Out:
#         Date  Student ID  Class Section  Study hrs  Percentage
# 0   1/7/2019      1001.0     10       A   2.000000        50.0
# 1   1/8/2019      1002.0     10     NaN   2.500000        80.0
# 2   1/9/2019      1003.0     10     NaN   3.000000        60.0
# 3  1/10/2019      1004.0     11     NaN   0.000000        65.0
# 4  1/11/2019      1005.0     11       A   4.000000        70.0
# 5  1/12/2019      1006.0     11       D  10.000000        75.0
# 6  1/13/2019      1007.0     12       B   4.000000        80.0
# 7  1/14/2019      1008.0     12       C   4.666667        90.0
# 8  1/15/2019      1009.0     12       A   5.333333        60.0
# 9  1/16/2019      1010.0     12       D   6.000000        85.0

# %%
df.interpolate(method='time')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-b2b35dd0218a> in <module>
# ----> 1 df.interpolate(method='time')
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7220                 "those NaNs before interpolating."
#    7221             )
# -> 7222         new_data = obj._mgr.interpolate(
#    7223             method=method,
#    7224             axis=axis,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py in interpolate(self, **kwargs)
#     591
#     592     def interpolate(self, **kwargs) -> "BlockManager":
# --> 593         return self.apply("interpolate", **kwargs)
#     594
#     595     def shift(self, periods: int, axis: int, fill_value) -> "BlockManager":
#
# ...

# %%
type(df['Date'][0])
# Out:
# str

# %%
df = pd.read_csv(r"C:\Users\Gitanshu\Downloads\Students_10.csv", parse_dates = ['Date'], index_col = ['Date'])
df
# Out:
#             Student ID  Class Section  Study hrs  Percentage
# Date
# 2019-01-07      1001.0     10       A        2.0        50.0
# 2019-01-08      1002.0     10     NaN        NaN        80.0
# 2019-01-09         NaN     10     NaN        3.0        60.0
# 2019-01-10         NaN     11     NaN        0.0         NaN
# 2019-01-11      1005.0     11       A        4.0         NaN
# 2019-01-12         NaN     11       D       10.0         NaN
# 2019-01-13      1007.0     12       B        4.0        80.0
# 2019-01-14      1008.0     12       C        NaN        90.0
# 2019-01-15      1009.0     12       A        NaN        60.0
# 2019-01-16      1010.0     12       D        6.0        85.0

# %%
type(df['Date'][0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-9a33f4475bcb> in <module>
# ...

# %%
df.interpolate(method='time')
# Out:
#             Student ID  Class Section  Study hrs  Percentage
# Date
# 2019-01-07      1001.0     10       A   2.000000        50.0
# 2019-01-08      1002.0     10     NaN   2.500000        80.0
# 2019-01-09      1003.0     10     NaN   3.000000        60.0
# 2019-01-10      1004.0     11     NaN   0.000000        65.0
# 2019-01-11      1005.0     11       A   4.000000        70.0
# 2019-01-12      1006.0     11       D  10.000000        75.0
# 2019-01-13      1007.0     12       B   4.000000        80.0
# 2019-01-14      1008.0     12       C   4.666667        90.0
# 2019-01-15      1009.0     12       A   5.333333        60.0
# 2019-01-16      1010.0     12       D   6.000000        85.0
