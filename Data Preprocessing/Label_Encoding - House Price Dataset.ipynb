# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
pd.set_option("display.max_rows",None)

# %%
data = pd.read_csv('train_house_price_prediction.csv')
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.keys()
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
data_2 = data[["KitchenQual","BldgType"]]

# %%
data_2.head()
# Out:
#   KitchenQual BldgType  BldgType_Le  KitchenQual_org_enc
# 0          Gd     1Fam            0                    3
# 1          TA     1Fam            0                    2
# 2          Gd     1Fam            0                    3
# 3          Gd     1Fam            0                    3
# 4          Gd     1Fam            0                    3

# %%
le = LabelEncoder()

# %%
le.fit_transform(data_2['BldgType'])
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
data_2["BldgType_Le"] = le.fit_transform(data_2['BldgType'])
data_2.head(20)
# Out:
# C:\Users\Gitanshu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    KitchenQual BldgType  BldgType_Le
# 0           Gd     1Fam            0
# 1           TA     1Fam            0
# 2           Gd     1Fam            0
# 3           Gd     1Fam            0
# 4           Gd     1Fam            0
# 5           TA     1Fam            0
# 6           Gd     1Fam            0
# 7           TA     1Fam            0
# 8           TA     1Fam            0
# 9           TA   2fmCon            1
# 10          TA     1Fam            0
# 11          Ex     1Fam            0
# 12          TA     1Fam            0
# ...

# %%
data_2["BldgType"].value_counts()
# Out:
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: BldgType, dtype: int64

# %%
data_2["KitchenQual"].value_counts()
# Out:
# TA    735
# Gd    586
# Ex    100
# Fa     39
# Name: KitchenQual, dtype: int64

# %%
'''
Kitchen Quality
    
    Ex - Excellent
    Gd - Good
    TA - Typical/Average
    Fa - Fair

'''

# %%
order_label = {"Ex":4,"Gd":3,"TA":2,"Fa":1}

# %%
data_2["KitchenQual_org_enc"] = data_2["KitchenQual"].map(order_label)
# Out:
# C:\Users\Gitanshu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_2.head()
# Out:
#   KitchenQual BldgType  BldgType_Le  KitchenQual_org_enc
# 0          Gd     1Fam            0                    3
# 1          TA     1Fam            0                    2
# 2          Gd     1Fam            0                    3
# 3          Gd     1Fam            0                    3
# 4          Gd     1Fam            0                    3
